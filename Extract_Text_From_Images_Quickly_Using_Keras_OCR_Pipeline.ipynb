# %% [markdown]
# <a href="https://colab.research.google.com/github/haddjyb2k/-APPLIED-DATA-SECIENCE-CAPSTONE/blob/main/Extract_Text_From_Images_Quickly_Using_Keras_OCR_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Extract-Text-From-Images-Quickly-Using-Keras-OCR-Pipeline

# %%
#Installing keras-ocr library
# !pip install -q keras-ocr
# Out:
#      |████████████████████████████████| 42 kB 1.0 MB/s
#      |████████████████████████████████| 604 kB 65.2 MB/s
#      |████████████████████████████████| 957 kB 68.6 MB/s
#      |████████████████████████████████| 9.5 MB 52.1 MB/s
#      |████████████████████████████████| 50 kB 4.3 MB/s
# ...

# %%
#importing required libraries
import keras_ocr
import matplotlib.pyplot as plt

# %%
# setup keras-ocr pipeline to process the images with pretrained weights for the detector and recognizer
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5

# %%
# Read images from folder path to image object
#images = [
    #keras_ocr.tools.read(img) for img in ['/content/Image1.png',
                                          #'/content/Image2.png',
   #]
#]

# %%
#https://d27jswm5an3efw.cloudfront.net/app/uploads/2019/07/insert-image-html.jpg

# %%
# Read images from folder path to image object
images = [
    keras_ocr.tools.read(img) for img in ['download.jpg','download1.png'
    ]
]

# %%
# Check image objects for images
from PIL import Image
# create figure
fig = plt.figure(figsize=(20, 10))
  
# setting values to rows and column variables
rows = 1
columns =2
  
# reading images
Image1 = Image.open('download.jpg')
Image2 = Image.open('download1.png')
  
# First Image
fig.add_subplot(rows, columns, 1)
plt.imshow(Image1)
plt.axis('off')
plt.title ("Handwritten Text")
  
# Second Image
fig.add_subplot(rows, columns, 2)
plt.imshow(Image2)
plt.axis('off')
plt.title ("Image with Text")
# Out:
# Text(0.5, 1.0, 'Image with Text')

# %%
# generate text predictions from the images
prediction_groups = pipeline.recognize(images)

# %%
# plot the text predictions
fig, axs = plt.subplots(ncols=len(images), figsize=(15, 10))
for ax, image, predictions in zip(axs, images, prediction_groups):
  keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)

# %% [markdown]
# The Keras-OCR library performed well on both images. It was able to correctly identify the text’s location and extract the words from the input images.
#
# We can also print the identified text from the images as –

# %%
predicted_image = prediction_groups[0]
for text, box in predicted_image:
    print(text)
# Out:
# if
# fast
# want
# to
# you
# go
# alone
# go
# if
# far
# want
# to
# you
# go
# together
# go

# %%
predicted_image = prediction_groups[1]
for text, box in predicted_image:
    print(text2)
# Out:
# image
# to
# text
# how
# to
# extract
# text
# from
# an
# image

# %%
#df = pd.read_csv('output_list.txt', sep=" ", header=None) or false

# %%
df = pd.read_csv('output_list.txt', sep=" ", header=None)
